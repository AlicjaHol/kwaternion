# %% [markdown]
# ## Wczytywanie danych

# %%
import pandas as pd
import os

# %%
df = pd.read_csv("https://raw.githubusercontent.com/AlicjaHol/kwaternion/master/pokemon_data.csv")

# %%
df.head(9)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# ...

# %%
df_txt = pd.read_csv("https://raw.githubusercontent.com/AlicjaHol/kwaternion/master/pokemon_data.txt", delimiter = "\t")

# %%
df_txt.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
os.getcwd()
# Out:
# 'C:\\Users\\alaho\\Desktop\\Ala\\analiza_danych\\kwaternion'

# %%
df_excel = pd.read_excel("pokemon_data.xlsx")

# %%
df_excel.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# ## Oczyszczanie danych

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# Zmieniamy nazwy kolumn żeby pozbyć się spacji i kropek.

# %%
df.columns = ['Number', 'Name', 'Type1', 'Type2', 'HP', 'Attack', 'Defense', 'Sp_Atk', 'Sp_Def', 'Speed', 'Generation', 'Legendary']

# %%
df.columns[1]
# Out:
# 'Name'

# %%
df.head()
# Out:
#    Number                   Name  Type1   Type2  HP  Attack  Defense  Sp_Atk  \
# 0       1              Bulbasaur  Grass  Poison  45      49       49      65
# 1       2                Ivysaur  Grass  Poison  60      62       63      80
# 2       3               Venusaur  Grass  Poison  80      82       83     100
# 3       3  VenusaurMega Venusaur  Grass  Poison  80     100      123     122
# 4       4             Charmander   Fire     NaN  39      52       43      60
#
#    Sp_Def  Speed  Generation  Legendary
# 0      65     45           1      False
# 1      80     60           1      False
# 2     100     80           1      False
# 3     120     80           1      False
# 4      50     65           1      False

# %%
pd.isna(df).sum()
# Out:
# Number          0
# Name            0
# Type1           0
# Type2         386
# HP              0
# Attack          0
# Defense         0
# Sp_Atk          0
# Sp_Def          0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# Sprawdziliśmy brakujące dane, nie ma potrzeby usuwania danych.

# %% [markdown]
# ## Podstawowe statystyki

# %%
df.describe()
# Out:
#            Number          HP      Attack     Defense      Sp_Atk      Sp_Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.describe(percentiles = [.1, .6, .99])
# Out:
#            Number          HP      Attack     Defense      Sp_Atk      Sp_Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 10%     73.900000   40.000000   40.000000   40.000000   35.000000   40.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 60%    431.400000   71.000000   85.000000   77.000000   75.000000   75.000000
# 99%    715.010000  150.000000  165.000000  180.000000  165.050000  150.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 10%     30.000000     1.00000
# ...

# %% [markdown]
# ## Odwoływanie do wierszy, kolumn itd

# %%
df.HP[2:5]
# Out:
# 2    80
# 3    80
# 4    39
# Name: HP, dtype: int64

# %%
df.Type1
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type1, Length: 800, dtype: object

# %%
df['Type1']
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type1, Length: 800, dtype: object

# %%
df.iloc[1, 1]
# Out:
# 'Ivysaur'

# %%
df.iloc[:, 1]
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df.loc[:, 'Type2']
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4         NaN
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type2, Length: 800, dtype: object

# %%
df.loc[1:7, 'Speed']
# Out:
# 1     60
# 2     80
# 3     80
# 4     65
# 5     80
# 6    100
# 7    100
# Name: Speed, dtype: int64

# %%
df.loc[2:8, ['Type1', 'Type2']]
# Out:
#    Type1   Type2
# 2  Grass  Poison
# 3  Grass  Poison
# 4   Fire     NaN
# 5   Fire     NaN
# 6   Fire  Flying
# 7   Fire  Dragon
# 8   Fire  Flying

# %%
df[df['Type1']=='Grass']
# Out:
#      Number                   Name  Type1     Type2   HP  Attack  Defense  \
# 0         1              Bulbasaur  Grass    Poison   45      49       49
# 1         2                Ivysaur  Grass    Poison   60      62       63
# 2         3               Venusaur  Grass    Poison   80      82       83
# 3         3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48       43                 Oddish  Grass    Poison   45      50       55
# ..      ...                    ...    ...       ...  ...     ...      ...
# 718     650                Chespin  Grass       NaN   56      61       65
# 719     651              Quilladin  Grass       NaN   61      78       95
# 720     652             Chesnaught  Grass  Fighting   88     107      122
# 740     672                 Skiddo  Grass       NaN   66      65       48
# 741     673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp_Atk  Sp_Def  Speed  Generation  Legendary
# ...

# %%
df[df.Type1.isin(['Grass', 'Fire'])]
# Out:
#      Number                   Name  Type1   Type2   HP  Attack  Defense  \
# 0         1              Bulbasaur  Grass  Poison   45      49       49
# 1         2                Ivysaur  Grass  Poison   60      62       63
# 2         3               Venusaur  Grass  Poison   80      82       83
# 3         3  VenusaurMega Venusaur  Grass  Poison   80     100      123
# 4         4             Charmander   Fire     NaN   39      52       43
# ..      ...                    ...    ...     ...  ...     ...      ...
# 735     667                 Litleo   Fire  Normal   62      50       58
# 736     668                 Pyroar   Fire  Normal   86      68       72
# 740     672                 Skiddo  Grass     NaN   66      65       48
# 741     673                 Gogoat  Grass     NaN  123     100       62
# 799     721              Volcanion   Fire   Water   80     110      120
#
#      Sp_Atk  Sp_Def  Speed  Generation  Legendary
# 0        65      65     45           1      False
# ...

# %%
df.HP.mean()
# Out:
# 69.25875

# %%
df.mean()
# Out:
# Number        362.81375
# HP             69.25875
# Attack         79.00125
# Defense        73.84250
# Sp_Atk         72.82000
# Sp_Def         71.90250
# Speed          68.27750
# Generation      3.32375
# Legendary       0.08125
# dtype: float64

# %%
df.Speed.max()
# Out:
# 180

# %%
df[df['Speed']==180]
# Out:
#      Number               Name    Type1 Type2  HP  Attack  Defense  Sp_Atk  \
# 431     386  DeoxysSpeed Forme  Psychic   NaN  50      95       90      95
#
#      Sp_Def  Speed  Generation  Legendary
# 431      90    180           3       True

# %% [markdown]
# ## Dodawanie nowej kolumny

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp_Atk'] + df['Sp_Def'] + df['Speed']

# %%
df.head()
# Out:
#    Number                   Name  Type1   Type2  HP  Attack  Defense  Sp_Atk  \
# 0       1              Bulbasaur  Grass  Poison  45      49       49      65
# 1       2                Ivysaur  Grass  Poison  60      62       63      80
# 2       3               Venusaur  Grass  Poison  80      82       83     100
# 3       3  VenusaurMega Venusaur  Grass  Poison  80     100      123     122
# 4       4             Charmander   Fire     NaN  39      52       43      60
#
#    Sp_Def  Speed  Generation  Legendary  Total
# 0      65     45           1      False    318
# 1      80     60           1      False    405
# 2     100     80           1      False    525
# 3     120     80           1      False    625
# 4      50     65           1      False    309

# %%
45+49+49+65+65+45
# Out:
# 318

# %%
df.to_csv("modified.csv", index = False)

# %%
new_df = df[df.Type1 == 'Dark']

# %%
new_df
# Out:
#      Number                   Name Type1     Type2   HP  Attack  Defense  \
# 212     197                Umbreon  Dark       NaN   95      65      110
# 213     198                Murkrow  Dark    Flying   60      85       42
# 233     215                Sneasel  Dark       Ice   55      95       55
# 246     228               Houndour  Dark      Fire   45      60       30
# 247     229               Houndoom  Dark      Fire   75      90       50
# 248     229  HoundoomMega Houndoom  Dark      Fire   75      90       90
# 284     261              Poochyena  Dark       NaN   35      55       35
# 285     262              Mightyena  Dark       NaN   70      90       70
# 326     302                Sableye  Dark     Ghost   50      75       75
# 327     302    SableyeMega Sableye  Dark     Ghost   50      85      125
# 392     359                  Absol  Dark       NaN   65     130       60
# 393     359        AbsolMega Absol  Dark       NaN   65     150       60
# ...

# %%
new_df.reset_index(drop = True, inplace = True)

# %%
new_df.head()
# Out:
#    Number      Name Type1   Type2  HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  \
# 0     197   Umbreon  Dark     NaN  95      65      110      60     130     65
# 1     198   Murkrow  Dark  Flying  60      85       42      85      42     91
# 2     215   Sneasel  Dark     Ice  55      95       55      35      75    115
# 3     228  Houndour  Dark    Fire  45      60       30      80      50     65
# 4     229  Houndoom  Dark    Fire  75      90       50     110      80     95
#
#    Generation  Legendary  Total
# 0           2      False    525
# 1           2      False    405
# 2           2      False    430
# 3           2      False    330
# 4           2      False    500

# %%
new_df.to_excel("poke_only_dark.xlsx", index = False)

# %%
df[(df.Legendary == False) & (df.Name.str.contains('Mega'))].sort_values(['Type1', 'Total'], ascending = [True, False])
# Out:
#      Number                       Name     Type1     Type2   HP  Attack  \
# 137     127          PinsirMega Pinsir       Bug    Flying   65     155
# 229     212          ScizorMega Scizor       Bug     Steel   70     150
# 232     214    HeracrossMega Heracross       Bug  Fighting   80     185
# 19       15      BeedrillMega Beedrill       Bug    Poison   65     150
# 248     229      HoundoomMega Houndoom      Dark      Fire   75      90
# 393     359            AbsolMega Absol      Dark       NaN   65     150
# 327     302        SableyeMega Sableye      Dark     Ghost   50      85
# 409     373    SalamenceMega Salamence    Dragon    Flying   95     145
# 494     445      GarchompMega Garchomp    Dragon    Ground  108     170
# 366     334        AltariaMega Altaria    Dragon     Fairy   75     110
# 196     181      AmpharosMega Ampharos  Electric    Dragon   90      95
# 339     310    ManectricMega Manectric  Electric       NaN   70      75
# ...

# %%
df[df.Name.str.contains('Mega')]
# Out:
#      Number                       Name     Type1     Type2   HP  Attack  \
# 3         3      VenusaurMega Venusaur     Grass    Poison   80     100
# 7         6  CharizardMega Charizard X      Fire    Dragon   78     130
# 8         6  CharizardMega Charizard Y      Fire    Flying   78     104
# 12        9    BlastoiseMega Blastoise     Water       NaN   79     103
# 19       15      BeedrillMega Beedrill       Bug    Poison   65     150
# 23       18        PidgeotMega Pidgeot    Normal    Flying   83      80
# 71       65      AlakazamMega Alakazam   Psychic       NaN   55      50
# 87       80        SlowbroMega Slowbro     Water   Psychic   95      75
# 102      94          GengarMega Gengar     Ghost    Poison   60      65
# 124     115  KangaskhanMega Kangaskhan    Normal       NaN  105     125
# 137     127          PinsirMega Pinsir       Bug    Flying   65     155
# 141     130      GyaradosMega Gyarados     Water      Dark   95     155
# ...
